# %% [markdown]
# # Universidad Politécnica Salesiana
# ### Nombre: Fernando Sanchez
# ### Materia: Sistema Expertos
# ### Cosine similarity
# ### Fecha: 15/02/2021
# ### Objetivo:
#
#     •	Consolidar los conocimientos adquiridos en clase de los sistemas expertos.

# %% [markdown]
# ## Importar la API py2neo
#     Para el ingreso de los datos que se encuentran dentro de la lista
# ## Conexión con Neo4j
#     Configure la URL de conexión con la base de datos de Ne04j:
#    ### graph = Graph("bolt://localhost:7687", aut="neo4j", password="costo", secure=False)

# %%
#IMPORTAR py2neo
from py2neo import Node, Relationship, Graph


# connect to authenticated graph database
graph = Graph("bolt://localhost:7687", aut="neo4j", password="costo", secure=False)

# %% [markdown]
#     Creación de los nodos Persona

# %%
graph.run("CREATE (Persona1:Persona{ persona_id: 1, persona_name:'Dave Brubeck', persona_embedding: [1,1,1,1]})").data()
# Out:
# []

# %%
graph.run("CREATE (Persona2:Persona{ persona_id: 2, persona_name:'Paul Desmond', persona_embedding: [12,30,14,100]})").data()
# Out:
# []

# %%
graph.run("CREATE (Persona3:Persona{ persona_id: 3, persona_name: null, persona_embedding: [1,1,1,2]})").data()
graph.run("CREATE (Persona4:Persona{ persona_id: 4, persona_name: null, persona_embedding: [2,2,2,3]})").data()
graph.run("CREATE (Persona5:Persona{ persona_id: 5, persona_name: null, persona_embedding: [3,3,3,3]})").data()
graph.run("CREATE (Persona6:Persona{ persona_id: 6, persona_name: null, persona_embedding: [1,1,1,10]})").data()
# Out:
# []

# %% [markdown]
#     Consultar los nodos creados:
#
# ![Captura%20de%20Pantalla%202021-02-15%20a%20la%28s%29%2002.19.11.png](attachment:Captura%20de%20Pantalla%202021-02-15%20a%20la%28s%29%2002.19.11.png)
#
#     Consultar los nodos en grafos:

# %% [markdown]
# ![Captura%20de%20Pantalla%202021-02-15%20a%20la%28s%29%2002.45.32.png](attachment:Captura%20de%20Pantalla%202021-02-15%20a%20la%28s%29%2002.45.32.png)

# %% [markdown]
#     Crear un gráfico de muestra:
#
# ![Captura%20de%20Pantalla%202021-02-15%20a%20la%28s%29%2002.51.49.png](attachment:Captura%20de%20Pantalla%202021-02-15%20a%20la%28s%29%2002.51.49.png)

# %% [markdown]
#     A continuación, encontrará la similitud entre las cuisines según la propiedad de incrustación:
#
# ![Captura%20de%20Pantalla%202021-02-15%20a%20la%28s%29%2002.35.28.png](attachment:Captura%20de%20Pantalla%202021-02-15%20a%20la%28s%29%2002.35.28.png)

# %% [markdown]
# ![Captura%20de%20Pantalla%202021-02-15%20a%20la%28s%29%2002.35.40.png](attachment:Captura%20de%20Pantalla%202021-02-15%20a%20la%28s%29%2002.35.40.png)

# %% [markdown]
# ![Captura%20de%20Pantalla%202021-02-15%20a%20la%28s%29%2002.35.51.png](attachment:Captura%20de%20Pantalla%202021-02-15%20a%20la%28s%29%2002.35.51.png)

# %% [markdown]
#     Realizar la siguiente consulta para calcular la similitud y crea relaciones is_similar entre el nodo p1 y
#     todos los demás nodos Person que no son p1:
#
#
# ![Captura%20de%20Pantalla%202021-02-15%20a%20la%28s%29%2003.07.46.png](attachment:Captura%20de%20Pantalla%202021-02-15%20a%20la%28s%29%2003.07.46.png)

# %% [markdown]
# ![Captura%20de%20Pantalla%202021-02-15%20a%20la%28s%29%2003.07.58.png](attachment:Captura%20de%20Pantalla%202021-02-15%20a%20la%28s%29%2003.07.58.png)

# %% [markdown]
#     Consultar la similaridad con el nombre de la persona 'Dave Brubeck':
#
# ![Captura%20de%20Pantalla%202021-02-15%20a%20la%28s%29%2003.08.55.png](attachment:Captura%20de%20Pantalla%202021-02-15%20a%20la%28s%29%2003.08.55.png)
